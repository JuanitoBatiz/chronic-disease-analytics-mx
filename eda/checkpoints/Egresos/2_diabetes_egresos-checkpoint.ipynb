# %%
import pandas as pd
import plotly.express as px

# %%
years = ["2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021", "2022", "2023"]
root = "C:/Users/uvm88/Desktop/Entregables/DATOS LIMPIOS 2013-2023/EGRESOS/DIABETES/EGRESOSDIABETES"
df_egresos_diabetes = []

for year in years:
    df_base_diabetes = pd.read_csv(root + year + ".csv")
    df_base_diabetes.insert(0, "año", year)
    df_egresos_diabetes.append(df_base_diabetes)
df_concat = pd.concat(df_egresos_diabetes)
df_concat = df_concat.reset_index().drop("index", axis = 1)
df_concat
# Out:
#          año        CLUES       INGRE      EGRESO  DIAS_ESTA  EDAD  CVEEDAD  \
# 0       2013  JCSSA002195  09/03/2013  09/03/2013          1    77        3
# 1       2013  JCSSA002195  11/05/2013  16/05/2013          5    67        3
# 2       2013  JCSSA002195  19/05/2013  23/05/2013          4    68        3
# 3       2013  JCSSA002195  18/05/2013  24/05/2013          6    40        3
# 4       2013  JCSSA002195  18/05/2013  24/05/2013          6    94        3
# ...      ...          ...         ...         ...        ...   ...      ...
# 620189  2023  PLSSA008485  2023-12-13  2023-12-22          9     5       42
# 620190  2023  PLSSA000863  2023-12-20  2023-12-26          6     5       42
# 620191  2023  TCSSA017420  2023-10-09  2023-10-11          2     5       70
# 620192  2023  TCSSA001064  2023-10-03  2023-10-10          7     5       37
# 620193  2023  TCSSA001064  2023-10-11  2023-10-11          1     5       33
#
# ...

# %%
df_lineplot = df_concat["año"].value_counts().reset_index()
df_lineplot.columns = ["año", "cantidad"]
df_lineplot = df_lineplot.sort_values("año", ignore_index = True)

# %%
fig_line = px.line(
              df_lineplot,
              x='año',
              y='cantidad',
              title='Linea temporal de la cantidad de egresos de diabetes (2013 - 2023)',
              template='plotly_white')


fig_line.update_layout(
    xaxis_title='Año',
    yaxis_title='Egresos',
    title_x=0.5 
)
fig_line.write_html("linea_temporal_egresos_diabetes.html")
fig_line.show()

# %%
df_concat = df_concat[(df_concat["EDAD"] < 112) & (df_concat["EDAD"] > 1)]

plotbox_m = px.box(
    df_concat,
    y = "EDAD",
    title = "Boxplot de egresos de diabetes por edad",
)

plotbox_m.update_layout(
    xaxis_title = "Personas",
    yaxis_title = "Edad",
    title_x = 0.5
)

plotbox_m.show()
plotbox_m.write_html("boxplot_egresos_diabetes_por_edad.html")

# %%
df_agrupado = df_concat.groupby("SEXO").size().reset_index(name="Cantidad")
mapeo = {
    1.0:"Hombres",
    2.0:"Mujeres",
}
df_agrupado["SEXO"] = df_agrupado["SEXO"].replace(mapeo)
df_agrupado = df_agrupado.drop([0, 3], axis = 0)
df_agrupado
# Out:
#       SEXO  Cantidad
# 1  Hombres    304836
# 2  Mujeres    315313

# %%
fig_defun = px.histogram(
    df_agrupado,
    x = "SEXO",
    y = "Cantidad",
    color = "SEXO",
    nbins = 2,
    barmode = "overlay",
    opacity = 0.6,
    title = "Distribución de egresos por género"
)

fig_defun.update_layout(
    xaxis_title="Género",
    yaxis_title="Egresos",
    title_x=0.5
)

fig_defun.show()
fig_defun.write_html("distribucion_egresos_diabetes_genero.html")
